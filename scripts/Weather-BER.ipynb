# %% [markdown]
# # Weather at Berlin Marathon

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/tageswerte_KL_00433_19480101_20241231_hist/produkt_klima_tag_19480101_20241231_00433.txt", sep=";", header=0)

# %%
df.head()
# Out:
#    STATIONS_ID  MESS_DATUM  QN_3     FX     FM  QN_4   RSK  RSKF    SDK  \
# 0          433    19480101  -999 -999.0 -999.0     5   5.7     8 -999.0
# 1          433    19480102  -999 -999.0 -999.0     5   3.3     1 -999.0
# 2          433    19480103  -999 -999.0 -999.0     5   4.0     1 -999.0
# 3          433    19480104  -999 -999.0 -999.0     5   0.2     1 -999.0
# 4          433    19480105  -999 -999.0 -999.0     5   2.0     1 -999.0
#
#    SHK_TAG    NM   VPM      PM   TMK   UPM   TXK   TNK   TGK  eor
# 0        4   5.0   4.9  1010.7  -1.8  89.0   0.8  -5.0  -4.7  eor
# 1        8   8.0   7.9   999.7   4.4  95.0   6.8  -2.7  -2.5  eor
# 2        0   5.3   9.8  1001.7   8.5  86.0  10.6   5.2   4.6  eor
# 3        0   8.0  10.2   999.8  10.2  83.0  11.5   6.6   4.7  eor
# 4        0   7.7   9.8   987.8  10.5  78.0  12.0   8.0   5.9  eor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28125 entries, 0 to 28124
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   STATIONS_ID  28125 non-null  int64
#  1   MESS_DATUM   28125 non-null  int64
#  2   QN_3         28125 non-null  int64
#  3     FX         28125 non-null  float64
#  4     FM         28125 non-null  float64
#  5   QN_4         28125 non-null  int64
#  6    RSK         28125 non-null  float64
#  7   RSKF         28125 non-null  int64
#  8    SDK         28125 non-null  float64
#  9   SHK_TAG      28125 non-null  int64
#  10    NM         28125 non-null  float64
#  11   VPM         28125 non-null  float64
#  12    PM         28125 non-null  float64
#  13   TMK         28125 non-null  float64
#  14   UPM         28125 non-null  float64
#  15   TXK         28125 non-null  float64
#  16   TNK         28125 non-null  float64
#  17   TGK         28125 non-null  float64
# ...

# %%
dates = df[
    (df['MESS_DATUM'] == 20110925) | 
    (df['MESS_DATUM'] == 20120930) | 
    (df['MESS_DATUM'] == 20130929) | 
    (df['MESS_DATUM'] == 20140928) | 
    (df['MESS_DATUM'] == 20150927) | 
    (df['MESS_DATUM'] == 20160925) | 
    (df['MESS_DATUM'] == 20170924) | 
    (df['MESS_DATUM'] == 20180916) | 
    (df['MESS_DATUM'] == 20190929) | 
    (df['MESS_DATUM'] == 20210926) | 
    (df['MESS_DATUM'] == 20220925) | 
    (df['MESS_DATUM'] == 20230924) | 
    (df['MESS_DATUM'] == 20240929)
    ]

# %%
dates
# Out:
#        STATIONS_ID  MESS_DATUM  QN_3    FX    FM  QN_4   RSK  RSKF    SDK  \
# 23278          433    20110925    10   5.5   1.7     9   0.0     0   10.4
# 23649          433    20120930    10   8.1   2.6     9   0.0     0    7.2
# 24013          433    20130929    10  10.9   4.4     9   0.0     0    9.4
# 24377          433    20140928    10   7.5   1.5     9   0.0     0    9.0
# 24741          433    20150927    10   7.3   2.3     9   0.0     0    8.4
# 25105          433    20160925    10   9.3   2.3     9   0.0     0   10.2
# 25469          433    20170924    10   6.9   3.0     9   1.4     4    0.9
# 25826          433    20180916    10   6.7   1.7     9   0.0     0    7.7
# 26204          433    20190929    10  10.5   3.5     9   8.0     4    0.7
# 26932          433    20210926    10   7.9   2.6     9   0.0     4    6.9
# 27296          433    20220925    10   6.6   2.4     9   0.0     6 -999.0
# 27660          433    20230924    10   7.5   2.1     9   0.0     0 -999.0
# ...

# %%
dates.columns = dates.columns.str.strip()

# %%
dates.sort_values(['TMK'], ascending=True)
# Out:
#        STATIONS_ID  MESS_DATUM  QN_3    FX   FM  QN_4  RSK  RSKF    SDK  \
# 24013          433    20130929    10  10.9  4.4     9  0.0     0    9.4
# 28031          433    20240929    10   7.3  2.8     9  0.0     0 -999.0
# 24741          433    20150927    10   7.3  2.3     9  0.0     0    8.4
# 23649          433    20120930    10   8.1  2.6     9  0.0     0    7.2
# 24377          433    20140928    10   7.5  1.5     9  0.0     0    9.0
# 27296          433    20220925    10   6.6  2.4     9  0.0     6 -999.0
# 27660          433    20230924    10   7.5  2.1     9  0.0     0 -999.0
# 25469          433    20170924    10   6.9  3.0     9  1.4     4    0.9
# 26204          433    20190929    10  10.5  3.5     9  8.0     4    0.7
# 23278          433    20110925    10   5.5  1.7     9  0.0     0   10.4
# 25105          433    20160925    10   9.3  2.3     9  0.0     0   10.2
# 25826          433    20180916    10   6.7  1.7     9  0.0     0    7.7
# ...

# %%
dates = dates[['MESS_DATUM', 'TMK']]

# %%
dates.to_csv("../data/processed/weather.csv")
